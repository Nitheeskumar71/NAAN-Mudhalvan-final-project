# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Flatten

# Example data for classification/prediction task
# Replace this with your own dataset
X_train = np.random.random((1000, 10, 1))  # Example features (assuming a sequence of length 10 with 1 feature)
y_train = np.random.randint(2, size=(1000,))  # Example labels (binary classification)

# Convolutional Neural Network (CNN)
cnn_model = Sequential([
    Conv1D(32, 3, activation='relu', input_shape=(10, 1)),
    MaxPooling1D(2),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the CNN model
cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 2s 5ms/step - loss: 0.6946 - accuracy: 0.4920
# Epoch 2/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6933 - accuracy: 0.5040
# Epoch 3/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6928 - accuracy: 0.5050
# Epoch 4/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6915 - accuracy: 0.5240
# Epoch 5/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6909 - accuracy: 0.5420
# Epoch 6/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6907 - accuracy: 0.5360
# Epoch 7/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 0.5440
# Epoch 8/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6888 - accuracy: 0.5500
# Epoch 9/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6879 - accuracy: 0.5510
# Epoch 10/10
# ...
